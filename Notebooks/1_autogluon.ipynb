# %% [markdown]
# # 1. Create the training sample

# %%
# %load_ext autoreload
# %autoreload 2

import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm
from tqdm.auto import tqdm
import sys
sys.path.append('/home/belle/zhangboy/inclusive_R_D/')
import utilities as util
plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.tab20.colors)

training_variables = util.training_variables
columns = util.all_relevant_variables
# Out:
# Welcome to JupyROOT 6.26/14

# %%
# Create Pandas DataFrames (df) from csv files and shuffle the rows
signal_region = '(1.855<D_M) & (D_M<1.885) & (B0_roeMbc_my_mask>5) & (B0_roeDeltae_my_mask<2)'
signal_region += ' & (B0_CMS2_weMbc>4.3) & (-3<B0_CMS0_weDeltae) & (B0_CMS0_weDeltae<2)'

sig_mc = uproot.concatenate([f'../Samples/Generic_MC15ri/e_channel/sigDDst_quaxo_2.root:B0'],
                          library="np",
                          cut = signal_region,
                          filter_branch=lambda branch: branch.name in columns)

generic_mc = uproot.concatenate([f'../Samples/Generic_MC15ri/e_channel/MC15ri_local_200fb_control/*.root:B0'],
                          library="np",
                          cut = signal_region,
                          filter_branch=lambda branch: branch.name in columns)

df_sig = pd.DataFrame(sig_mc)
df_generic = pd.DataFrame(generic_mc)

# %%
# separate components
sig_samples=util.get_dataframe_samples_new(df_sig, 'e', template=False)
bkg_samples=util.get_dataframe_samples_new(df_generic, 'e', template=False)

train_dic = {r'$D\tau\nu$':       sig_samples[r'$D\tau\nu$'],
             'bkg_FakeD':         bkg_samples['bkg_FakeD'].sample(frac=0.5,random_state=0),
             'bkg_combinatorial': bkg_samples['bkg_combinatorial'], 
             'bkg_continuum':     bkg_samples['bkg_continuum'],
             'bkg_singleBbkg':    bkg_samples['bkg_singleBbkg'],
             'bkg_TDFl':          bkg_samples['bkg_TDFl'],
             'bkg_fakeTracks':    bkg_samples['bkg_fakeTracks']}

for name, df in train_dic.items():
    print(name, df.iloc[0]['mode'], len(df))
# Out:
# $D\tau\nu$ 8 57718
# bkg_FakeD 1 421298
# bkg_combinatorial 4 91828
# bkg_continuum 3 69691
# bkg_singleBbkg 5 36815
# bkg_TDFl 2 26843
# bkg_fakeTracks 0 25743

# %%
# create the trainig sample and shuffle, use 'mode' as the training label
df_train = pd.concat( list(train_dic.values()) ).sample(frac=1)

# %%
df_train['mode'].value_counts()
# Out:
# mode
# 1    421298
# 4     91828
# 3     69691
# 8     57718
# 5     36815
# 2     26843
# 0     25743
# Name: count, dtype: int64

# %%
print(df_train.isna().sum()[df_train.isna().sum()!=0])
# Out:
# B0_mcDaughter_0_PDG    26546
# B0_mcDaughter_1_PDG    26546
# B0_mcPDG               26546
# D_K_mcPDG               4840
# D_mcPDG                21614
# ell_mcPDG               3405
# dtype: int64

# %%
# define relevant variables to your training
target_column = ['mode']
feature_column = training_variables

df_train_sub = df_train[target_column + feature_column].copy().reset_index(drop=True)

# %%
with uproot.recreate(f'../AutogluonModels/train.root') as file:
    file['B0'] = df_train_sub

# %% [markdown]
# # 2. Setup autogluon and perfrom the training

# %%
from autogluon.tabular import TabularPredictor
import uproot
import pandas as pd

train_sub = uproot.concatenate([f'../AutogluonModels/train.root:B0'],library="np")
df_train_sub = pd.DataFrame({k:v for k, v in train_sub.items() if k!='index'})

# Split the training set to train and validation
train_data = df_train_sub.sample(frac=0.8, random_state=0)
validation_data = df_train_sub.drop(train_data.index)

# %%
# Define and fit the AutoGluon classifier
hyperpar = {
    "GBM": {
        "num_boost_round": 500,
        "early_stopping_rounds": 20,
        "learning_rate": 0.05,  # Lower learning rate
        "min_data_in_leaf": 20,
        'max_depth': 6,
        "lambda_l1": 1,        # L1 regularization
        "lambda_l2": 1         # L2 regularization
        'lambda_l1': 1e-2,
        'lambda_l2': 1e-2,
    },
    'CAT': {
        'iterations': 500,
        'od_type': 'Iter',
        'od_wait': 20,
    },
    'XGB': {
        'learning_rate': 0.05,
        'n_estimators': 500,
        'early_stopping_rounds': 20,
        'reg_alpha': 1e-2,
        'reg_lambda': 1e-2,
    },
    "NN_TORCH": {
        "num_epochs": 50,
        'num_layers': 2,
        'hidden_size': 128,
        "early_stop_patience": 5,
        "dropout_prob": 0.5,       # Add dropout to reduce overfitting
        "batch_size": 32,
        "weight_decay": 1e-4,      # Apply L2 regularization
        "learning_rate": 0.001,     # Adjust learning rate
        'lr_scheduler': 'CosineAnnealingLR',  # or other supported schedulers
        'lr_scheduler_params': {
            'T_max': 50,
        }
    }
}

hyperpar_tuner = {
        'num_trials': 20,
        'scheduler': 'local',
        'searcher': 'random',
    }

ag = TabularPredictor(label='mode', eval_metric='f1_macro') # many more configuration
predictor = ag.fit(train_data, presets='good_quality', save_bag_folds=True,
                   excluded_model_types=['FASTAI'],time_limit=600,
                   hyperparameters=hyperpar,
                   hyperparameter_tune_kwargs=hyperpar_tuner)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241122_083841"
# Presets specified: ['good_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels/ag-20241122_083841/ds_sub_fit/sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 493 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 107 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 107s
# AutoGluon will save models to "AutogluonModels/ag-20241122_083841"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.8.8
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Tue Oct 3 11:12:36 EDT 2023
# CPU Count:          128
# Memory Avail:       169.06 GB / 502.95 GB (33.6%)
# Disk Space Avail:   102281.84 GB / 197682.00 GB (51.7%)
# ===================================================
# Train Data Rows:    583949
# Train Data Columns: 44
# Label Column:       mode
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 7
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    173266.92 MB
# 	Train Data (Original)  Memory Usage: 98.01 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 44 | ['B0_R2', 'B0_thrustOm', 'B0_cosTBTO', 'B0_cosTBz', 'B0_KSFWV3', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 44 | ['B0_R2', 'B0_thrustOm', 'B0_cosTBTO', 'B0_cosTBz', 'B0_KSFWV3', ...]
# 	1.5s = Fit runtime
# 	44 features in original data used to generate 44 features in processed data.
# 	Train Data (Processed) Memory Usage: 98.01 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 1.65s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1_macro'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 70.21s of the 105.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=16, gpus=0, memory=0.65%)
# 	0.368	 = Validation score   (f1_macro)
# 	53.62s	 = Training   runtime
# 	2.13s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 105.35s of the 24.46s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# 	0.368	 = Validation score   (f1_macro)
# 	0.15s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting 11 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 24.16s of the 24.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=16, gpus=0, memory=0.76%)
# 	0.3661	 = Validation score   (f1_macro)
# 	14.68s	 = Training   runtime
# 	2.24s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 105.35s of the 0.23s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# 	0.368	 = Validation score   (f1_macro)
# 	8.1s	 = Training   runtime
# 	0.13s	 = Validation runtime
# AutoGluon training complete, total runtime = 118.3s ... Best model: "WeightedEnsemble_L2"
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	39.17s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# 	0.15s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	8.96s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# 	8.1s	 = Training   runtime
# Updated best model to "NeuralNetFastAI_BAG_L1_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "NeuralNetFastAI_BAG_L1_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 50.02s ... Best model: "NeuralNetFastAI_BAG_L1_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241122_083841")

# %% [markdown]
# # 3. Load and inspect model

# %%
predictor = TabularPredictor.load("../AutogluonModels/ag-20241122_085044")

# %%
# display the trained models
predictor.leaderboard(validation_data, extra_metrics=['roc_auc_ovo_macro','balanced_accuracy'])
# Out:
#                        model  score_test  roc_auc_ovo_macro  \
# 0       LightGBM_BAG_L1_FULL    0.393774           0.832627
# 1   WeightedEnsemble_L2_FULL    0.393774           0.832627
# 2   WeightedEnsemble_L3_FULL    0.393774           0.832627
# 3          LightGBMXT_BAG_L1    0.392849           0.834741
# 4            LightGBM_BAG_L1    0.392524           0.833781
# 5        WeightedEnsemble_L2    0.392524           0.833781
# 6        WeightedEnsemble_L3    0.392524           0.833781
# 7     LightGBMXT_BAG_L1_FULL    0.392194           0.833554
# 8       LightGBM_BAG_L2_FULL    0.391896           0.835256
# 9            LightGBM_BAG_L2    0.390768           0.837974
# 10    LightGBMXT_BAG_L2_FULL    0.388714           0.837285
# 11         LightGBMXT_BAG_L2    0.384470           0.837805
#
#     balanced_accuracy  score_val eval_metric  pred_time_test  pred_time_val  \
# 0            0.375637        NaN    f1_macro        0.832892            NaN
# 1            0.375637        NaN    f1_macro        0.856180            NaN
# 2            0.375637        NaN    f1_macro        0.859019            NaN
# 3            0.375076   0.394411    f1_macro       15.299670    1530.492718
# 4            0.374904   0.395633    f1_macro        6.421356     563.666807
# 5            0.374904   0.395633    f1_macro        6.442960     563.799349
# 6            0.374904   0.395633    f1_macro        6.466001     563.796647
# 7            0.374755        NaN    f1_macro        1.423460            NaN
# 8            0.378817        NaN    f1_macro        3.202905            NaN
# 9            0.378746   0.392154    f1_macro       29.169917    2103.727971
# 10           0.377459        NaN    f1_macro        3.215204            NaN
# 11           0.374860   0.386630    f1_macro       33.859720    2157.313442
#
#        fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0     28.590117                 0.832892                     NaN
# 1     36.702713                 0.023288                     NaN
# 2     43.920925                 0.026127                     NaN
# 3   2805.307317                15.299670             1530.492718
# 4    388.340183                 6.421356              563.666807
# 5    396.452779                 0.021604                0.132542
# 6    403.670991                 0.044645                0.129839
# 7     50.589496                 1.423460                     NaN
# 8    118.387522                 0.946553                     NaN
# 9   3435.610131                 7.448891                9.568446
# 10   119.068892                 0.958851                     NaN
# 11  4508.709380                12.138694               63.153918
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0           28.590117            1       True          8
# 1            8.112596            2       True          9
# 2           15.330808            3       True         12
# 3         2805.307317            1       True          1
# 4          388.340183            1       True          2
# 5            8.112596            2       True          3
# 6           15.330808            3       True          6
# 7           50.589496            1       True          7
# 8           39.207910            2       True         11
# 9          241.962631            2       True          5
# 10          39.889279            2       True         10
# 11        1315.061881            2       True          4

# %%
# display the trained models
predictor.leaderboard(validation_data, extra_metrics=['roc_auc_ovo_macro','balanced_accuracy'])
# Out:
#                           model  score_test  roc_auc_ovo_macro  \
# 0        NeuralNetFastAI_BAG_L2    0.413156           0.841535
# 1           WeightedEnsemble_L3    0.413156           0.841535
# 2               LightGBM_BAG_L2    0.389424           0.842302
# 3             LightGBMXT_BAG_L2    0.387497           0.842365
# 4             LightGBMXT_BAG_L1    0.385262           0.831248
# 5           WeightedEnsemble_L2    0.385262           0.831248
# 6          LightGBM_BAG_L2_FULL    0.385091           0.840151
# 7        LightGBMXT_BAG_L2_FULL    0.384012           0.840050
# 8        LightGBMXT_BAG_L1_FULL    0.383193           0.830669
# 9      WeightedEnsemble_L2_FULL    0.383193           0.830669
# 10  NeuralNetFastAI_BAG_L2_FULL    0.381937           0.839405
# 11     WeightedEnsemble_L3_FULL    0.381937           0.839405
# 12       NeuralNetFastAI_BAG_L1    0.378960           0.837937
# 13  NeuralNetFastAI_BAG_L1_FULL    0.371061           0.833524
#
#     balanced_accuracy  score_val eval_metric  pred_time_test  pred_time_val  \
# 0            0.396298   0.412699    f1_macro       16.515323     217.615295
# 1            0.396298   0.412699    f1_macro       16.543453     217.746156
# 2            0.379818   0.391058    f1_macro       13.010087     136.243930
# 3            0.378457   0.388879    f1_macro       14.283112     242.426528
# 4            0.367961   0.385665    f1_macro        5.967541      14.706898
# 5            0.367961   0.385665    f1_macro        6.003815      14.836629
# 6            0.376995        NaN    f1_macro        1.702802            NaN
# 7            0.376155        NaN    f1_macro        1.935358            NaN
# 8            0.366397        NaN    f1_macro        0.767725            NaN
# 9            0.366397        NaN    f1_macro        0.813939            NaN
# 10           0.384781        NaN    f1_macro        2.137335            NaN
# 11           0.384781        NaN    f1_macro        2.154323            NaN
# 12           0.373763   0.377297    f1_macro        4.847506     118.375250
# 13           0.369031        NaN    f1_macro        0.644300            NaN
#
#        fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   3374.677931                 5.700277               84.533147
# 1   3393.703473                 0.028129                0.130861
# 2   2580.149384                 2.195041                3.161782
# 3   2886.443301                 3.468066              109.344380
# 4     74.360766                 5.967541               14.706898
# 5     82.575466                 0.036275                0.129731
# 6    492.900146                 0.290777                     NaN
# 7   1142.132465                 0.523333                     NaN
# 8     21.813005                 0.767725                     NaN
# 9     30.027705                 0.046214                     NaN
# 10  4707.602019                 0.725310                     NaN
# 11  4726.627561                 0.016988                     NaN
# 12  2474.544634                 4.847506              118.375250
# 13   163.591689                 0.644300                     NaN
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0          825.772531            2       True          4
# 1           19.025541            3       True          7
# 2           31.243984            2       True          6
# 3          337.537901            2       True          5
# 4           74.360766            1       True          2
# 5            8.214700            2       True          3
# 6          307.495451            2       True         13
# 7          956.727770            2       True         12
# 8           21.813005            1       True          9
# 9            8.214700            2       True         10
# 10        4522.197325            2       True         11
# 11          19.025541            3       True         14
# 12        2474.544634            1       True          1
# 13         163.591689            1       True          8

# %%
predictor.model_best
# Out:
# 'LightGBM_BAG_L1_FULL'

# %%
predictor.feature_importance(validation_data)
# Out:
# Computing feature importance via permutation shuffling for 44 features using 5000 rows with 5 shuffle sets...
# 	13.39s	= Expected runtime (2.68s per shuffle set)
# 	6.23s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                            importance    stddev   p_value  n  p99_high  \
# B0_roeDeltae_my_mask         0.054594  0.006399  0.000022  5  0.067769
# B0_roeMbc_my_mask            0.043414  0.004393  0.000012  5  0.052459
# D_daughterInvM_0_1           0.029828  0.002667  0.000008  5  0.035320
# D_daughterInvM_1_2           0.028310  0.005647  0.000180  5  0.039936
# D_A1FflightDistanceSig_IP    0.026893  0.012865  0.004743  5  0.053382
# B0_vtxDDSig                  0.026874  0.009656  0.001697  5  0.046755
# B0_R2                        0.023055  0.002275  0.000011  5  0.027738
# B0_KSFWV14                   0.021329  0.005471  0.000477  5  0.032594
# D_pi1_pValue                 0.016919  0.003883  0.000311  5  0.024914
# B0_vtxReChi2                 0.013495  0.003449  0.000471  5  0.020597
# D_vtxReChi2                  0.013164  0.003785  0.000737  5  0.020957
# D_pi2_pValue                 0.011089  0.005659  0.005929  5  0.022740
# B0_KSFWV4                    0.010048  0.005092  0.005789  5  0.020532
# B0_KSFWV8                    0.007635  0.005260  0.015755  5  0.018467
# B0_flightDistanceSig         0.006774  0.005785  0.029451  5  0.018685
# B0_CC1                       0.006310  0.001824  0.000752  5  0.010066
# B0_KSFWV5                    0.005056  0.001416  0.000668  5  0.007972
# B0_cosTBz                    0.004864  0.001409  0.000757  5  0.007765
# B0_CC4                       0.004580  0.002465  0.007105  5  0.009656
# B0_KSFWV3                    0.004454  0.003211  0.018079  5  0.011065
# B0_roeEextra_my_mask         0.004158  0.004859  0.064089  5  0.014162
# B0_CC6                       0.003418  0.003356  0.042523  5  0.010329
# B0_CC2                       0.002795  0.004317  0.110621  5  0.011685
# B0_TagVReChi2IP              0.002633  0.005096  0.156173  5  0.013126
# B0_CC3                       0.002396  0.004366  0.143564  5  0.011385
# B0_Lab5_weMissPTheta         0.002159  0.001981  0.035722  5  0.006237
# B0_KSFWV15                   0.001837  0.002700  0.101441  5  0.007397
# B0_CC5                       0.001548  0.005117  0.267876  5  0.012085
# D_K_pValue                   0.001510  0.002657  0.136316  5  0.006982
# B0_KSFWV9                    0.001488  0.003917  0.221737  5  0.009553
# B0_thrustOm                  0.001086  0.004480  0.308300  5  0.010310
# B0_KSFWV7                    0.001017  0.002008  0.160430  5  0.005152
# B0_CC8                       0.000820  0.002703  0.267339  5  0.006386
# B0_cosTBTO                   0.000811  0.003807  0.329388  5  0.008648
# B0_KSFWV16                   0.000768  0.004167  0.350782  5  0.009348
# B0_KSFWV6                    0.000738  0.001088  0.102048  5  0.002979
# B0_KSFWV13                   0.000697  0.002163  0.255661  5  0.005151
# B0_CC9                       0.000492  0.001550  0.258664  5  0.003683
# B0_roeCharge_my_mask         0.000483  0.001348  0.234098  5  0.003259
# B0_KSFWV10                   0.000475  0.001830  0.296377  5  0.004242
# B0_KSFWV18                   0.000352  0.001143  0.264644  5  0.002706
# B0_KSFWV17                   0.000036  0.001266  0.476265  5  0.002643
# B0_CC7                      -0.000297  0.002107  0.615873  5  0.004042
# B0_roel_DistanceSig_dis     -0.000448  0.002158  0.666577  5  0.003996
#
#                             p99_low
# B0_roeDeltae_my_mask       0.041418
# B0_roeMbc_my_mask          0.034370
# D_daughterInvM_0_1         0.024336
# D_daughterInvM_1_2         0.016683
# D_A1FflightDistanceSig_IP  0.000405
# B0_vtxDDSig                0.006993
# B0_R2                      0.018371
# B0_KSFWV14                 0.010065
# D_pi1_pValue               0.008924
# B0_vtxReChi2               0.006392
# D_vtxReChi2                0.005371
# D_pi2_pValue              -0.000563
# B0_KSFWV4                 -0.000436
# B0_KSFWV8                 -0.003196
# B0_flightDistanceSig      -0.005137
# B0_CC1                     0.002555
# B0_KSFWV5                  0.002140
# B0_cosTBz                  0.001964
# B0_CC4                    -0.000496
# B0_KSFWV3                 -0.002157
# B0_roeEextra_my_mask      -0.005845
# B0_CC6                    -0.003493
# B0_CC2                    -0.006094
# B0_TagVReChi2IP           -0.007861
# B0_CC3                    -0.006594
# B0_Lab5_weMissPTheta      -0.001920
# B0_KSFWV15                -0.003723
# B0_CC5                    -0.008988
# D_K_pValue                -0.003961
# B0_KSFWV9                 -0.006577
# B0_thrustOm               -0.008139
# B0_KSFWV7                 -0.003119
# B0_CC8                    -0.004745
# B0_cosTBTO                -0.007027
# B0_KSFWV16                -0.007813
# B0_KSFWV6                 -0.001503
# B0_KSFWV13                -0.003758
# B0_CC9                    -0.002699
# B0_roeCharge_my_mask      -0.002294
# B0_KSFWV10                -0.003293
# B0_KSFWV18                -0.002002
# B0_KSFWV17                -0.002571
# B0_CC7                    -0.004636
# B0_roel_DistanceSig_dis   -0.004892

# %%
predictor.feature_importance(validation_data,'WeightedEnsemble_L3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2864688/88770798.py in <module>
# ----> 1 predictor.feature_importance(validation_data,'WeightedEnsemble_L3')
#
# ~/.local/lib/python3.8/site-packages/autogluon/tabular/predictor/predictor.py in feature_importance(self, data, model, features, feature_stage, subsample_size, time_limit, num_shuffle_sets, include_confidence_band, confidence_level, silent)
#    2944             num_shuffle_sets = 10 if time_limit else 5
#    2945
# -> 2946         fi_df = self._learner.get_feature_importance(
#    2947             model=model,
#    2948             X=data,
#
# ~/.local/lib/python3.8/site-packages/autogluon/tabular/learner/abstract_learner.py in get_feature_importance(self, model, X, y, features, feature_stage, subsample_size, silent, **kwargs)
#     918
#     919             if feature_stage == "original":
# --> 920                 return trainer._get_feature_importance_raw(
#     921                     model=model, X=X, y=y, features=features, subsample_size=subsample_size, transform_func=self.transform_features, silent=silent, **kwargs
#     922                 )
#
# ~/.local/lib/python3.8/site-packages/autogluon/core/trainer/abstract_trainer.py in _get_feature_importance_raw(self, X, y, model, eval_metric, **kwargs)
#    2792         model: AbstractModel = self.load_model(model)
#    2793         predict_func_kwargs = dict(model=model)
# -> 2794         return compute_permutation_feature_importance(
#    2795             X=X,
#    2796             y=y,
#
# ~/.local/lib/python3.8/site-packages/autogluon/core/utils/utils.py in compute_permutation_feature_importance(X, y, predict_func, eval_metric, features, subsample_size, num_shuffle_sets, predict_func_kwargs, transform_func, transform_func_kwargs, time_limit, silent, log_prefix, importance_as_list, random_state, **kwargs)
#     842             time_start_score = time.time()
#     843             X_transformed = X if transform_func is None else transform_func(X, **transform_func_kwargs)
# --> 844             y_pred = predict_func(X_transformed, **predict_func_kwargs)
#     845             score_baseline = eval_metric(y, y_pred, **kwargs)
#     846             if shuffle_repeat == 0:
#
# ~/.local/lib/python3.8/site-packages/autogluon/core/trainer/abstract_trainer.py in predict(self, X, model)
#     829             model = self._get_best()
#     830         cascade = isinstance(model, list)
# --> 831         return self._predict_model(X, model, cascade=cascade)
#     832
#     833     def predict_proba(self, X, model=None):
#
# ~/.local/lib/python3.8/site-packages/autogluon/core/trainer/abstract_trainer.py in _predict_model(self, X, model, model_pred_proba_dict, cascade)
#    2606
#    2607     def _predict_model(self, X, model, model_pred_proba_dict=None, cascade=False):
# -> 2608         y_pred_proba = self._predict_proba_model(X=X, model=model, model_pred_proba_dict=model_pred_proba_dict, cascade=cascade)
#    2609         return get_pred_from_proba(y_pred_proba=y_pred_proba, problem_type=self.problem_type)
#    2610
#
# ~/.local/lib/python3.8/site-packages/autogluon/core/trainer/abstract_trainer.py in _predict_proba_model(self, X, model, model_pred_proba_dict, cascade)
#    2610
#    2611     def _predict_proba_model(self, X, model, model_pred_proba_dict=None, cascade=False):
# -> 2612         return self.get_pred_proba_from_model(model=model, X=X, model_pred_proba_dict=model_pred_proba_dict, cascade=cascade)
#    2613
#    2614     def _proxy_model_feature_prune(
#
# ~/.local/lib/python3.8/site-packages/autogluon/core/trainer/abstract_trainer.py in get_pred_proba_from_model(self, model, X, model_pred_proba_dict, cascade)
#     849         else:
#     850             models = [model]
# --> 851         model_pred_proba_dict = self.get_model_pred_proba_dict(X=X, models=models, model_pred_proba_dict=model_pred_proba_dict, cascade=cascade)
#     852         if not isinstance(model, str):
#     853             model = model.name
#
# ~/.local/lib/python3.8/site-packages/autogluon/core/trainer/abstract_trainer.py in get_model_pred_proba_dict(self, X, models, model_pred_proba_dict, model_pred_time_dict, record_pred_time, use_val_cache, cascade, cascade_threshold)
#    1098                 else:
#    1099                     preprocess_kwargs = dict(infer=False, model_pred_proba_dict=model_pred_proba_dict)
# -> 1100                 model_pred_proba_dict[model_name] = model.predict_proba(X, **preprocess_kwargs)
#    1101             else:
#    1102                 model_pred_proba_dict[model_name] = model.predict_proba(X)
#
# ~/.local/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py in predict_proba(self, X, normalize, **kwargs)
#     452         model = self.load_child(self.models[0])
#     453         X = self.preprocess(X, model=model, **kwargs)
# --> 454         pred_proba = model.predict_proba(X=X, preprocess_nonadaptive=False, normalize=normalize)
#     455         for model in self.models[1:]:
#     456             model = self.load_child(model)
#
# ~/.local/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py in predict_proba(self, X, normalize, **kwargs)
#     948         if normalize is None:
#     949             normalize = self.normalize_pred_probas
# --> 950         y_pred_proba = self._predict_proba(X=X, **kwargs)
#     951         if normalize:
#     952             y_pred_proba = normalize_pred_probas(y_pred_proba, self.problem_type)
#
# ~/.local/lib/python3.8/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py in _predict_proba(self, X, **kwargs)
#     483         with self.model.no_bar():
#     484             with self.model.no_logging():
# --> 485                 preds, _ = self.model.get_preds(dl=test_dl)
#     486         if single_row:
#     487             preds = preds[:1, :]
#
# ~/.local/lib/python3.8/site-packages/fastai/learner.py in get_preds(self, ds_idx, dl, with_input, with_decoded, with_loss, act, inner, reorder, cbs, **kwargs)
#     307         ctx_mgrs = self.validation_context(cbs=L(cbs)+[cb], inner=inner)
#     308         if with_loss: ctx_mgrs.append(self.loss_not_reduced())
# --> 309         with ContextManagers(ctx_mgrs):
#     310             self._do_epoch_validate(dl=dl)
#     311             if act is None: act = getcallable(self.loss_func, 'activation')
#
# ~/.local/lib/python3.8/site-packages/fastcore/xtras.py in __enter__(self)
#     620     "Wrapper for `contextlib.ExitStack` which enters a collection of context managers"
#     621     def __init__(self, mgrs): self.default,self.stack = L(mgrs),ExitStack()
# --> 622     def __enter__(self): self.default.map(self.stack.enter_context)
#     623     def __exit__(self, *args, **kwargs): self.stack.__exit__(*args, **kwargs)
#     624
#
# ~/.local/lib/python3.8/site-packages/fastcore/foundation.py in map(self, f, *args, **kwargs)
#     157     def range(cls, a, b=None, step=None): return cls(range_of(a, b=b, step=step))
#     158
# --> 159     def map(self, f, *args, **kwargs): return self._new(map_ex(self, f, *args, gen=False, **kwargs))
#     160     def argwhere(self, f, negate=False, **kwargs): return self._new(argwhere(self, f, negate, **kwargs))
#     161     def argfirst(self, f, negate=False):
#
# ~/.local/lib/python3.8/site-packages/fastcore/basics.py in map_ex(iterable, f, gen, *args, **kwargs)
#     908     res = map(g, iterable)
#     909     if gen: return res
# --> 910     return list(res)
#     911
#     912 # %% ../nbs/01_basics.ipynb
#
# ~/.local/lib/python3.8/site-packages/fastcore/basics.py in __call__(self, *args, **kwargs)
#     893             if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     894         fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 895         return self.func(*fargs, **kwargs)
#     896
#     897 # %% ../nbs/01_basics.ipynb
#
# /cvmfs/belle.cern.ch/el9/externals/v02-01-00/Linux_x86_64/common/lib/python3.8/contextlib.py in enter_context(self, cm)
#     423         _cm_type = type(cm)
#     424         _exit = _cm_type.__exit__
# --> 425         result = _cm_type.__enter__(cm)
#     426         self._push_cm_exit(cm, _exit)
#     427         return result
#
# ~/.local/lib/python3.8/site-packages/fastcore/xtras.py in __enter__(self)
#     620     "Wrapper for `contextlib.ExitStack` which enters a collection of context managers"
#     621     def __init__(self, mgrs): self.default,self.stack = L(mgrs),ExitStack()
# --> 622     def __enter__(self): self.default.map(self.stack.enter_context)
#     623     def __exit__(self, *args, **kwargs): self.stack.__exit__(*args, **kwargs)
#     624
#
# ~/.local/lib/python3.8/site-packages/fastcore/foundation.py in map(self, f, *args, **kwargs)
#     157     def range(cls, a, b=None, step=None): return cls(range_of(a, b=b, step=step))
#     158
# --> 159     def map(self, f, *args, **kwargs): return self._new(map_ex(self, f, *args, gen=False, **kwargs))
#     160     def argwhere(self, f, negate=False, **kwargs): return self._new(argwhere(self, f, negate, **kwargs))
#     161     def argfirst(self, f, negate=False):
#
# ~/.local/lib/python3.8/site-packages/fastcore/basics.py in map_ex(iterable, f, gen, *args, **kwargs)
#     908     res = map(g, iterable)
#     909     if gen: return res
# --> 910     return list(res)
#     911
#     912 # %% ../nbs/01_basics.ipynb
#
# ~/.local/lib/python3.8/site-packages/fastcore/basics.py in __call__(self, *args, **kwargs)
#     893             if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     894         fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 895         return self.func(*fargs, **kwargs)
#     896
#     897 # %% ../nbs/01_basics.ipynb
#
# /cvmfs/belle.cern.ch/el9/externals/v02-01-00/Linux_x86_64/common/lib/python3.8/contextlib.py in enter_context(self, cm)
#     423         _cm_type = type(cm)
#     424         _exit = _cm_type.__exit__
# --> 425         result = _cm_type.__enter__(cm)
#     426         self._push_cm_exit(cm, _exit)
#     427         return result
#
# ~/.local/lib/python3.8/site-packages/fastai/learner.py in __enter__(self)
#     267
#     268     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
# --> 269     def __enter__(self): self(_before_epoch); return self
#     270     def __exit__(self, exc_type, exc_value, tb): self(_after_epoch)
#     271
#
# ~/.local/lib/python3.8/site-packages/fastai/learner.py in __call__(self, event_name)
#     172
#     173     def ordered_cbs(self, event): return [cb for cb in self.cbs.sorted('order') if hasattr(cb, event)]
# --> 174     def __call__(self, event_name): L(event_name).map(self._call_one)
#     175
#     176     def _call_one(self, event_name):
#
# ~/.local/lib/python3.8/site-packages/fastcore/foundation.py in map(self, f, *args, **kwargs)
#     157     def range(cls, a, b=None, step=None): return cls(range_of(a, b=b, step=step))
#     158
# --> 159     def map(self, f, *args, **kwargs): return self._new(map_ex(self, f, *args, gen=False, **kwargs))
#     160     def argwhere(self, f, negate=False, **kwargs): return self._new(argwhere(self, f, negate, **kwargs))
#     161     def argfirst(self, f, negate=False):
#
# ~/.local/lib/python3.8/site-packages/fastcore/basics.py in map_ex(iterable, f, gen, *args, **kwargs)
#     908     res = map(g, iterable)
#     909     if gen: return res
# --> 910     return list(res)
#     911
#     912 # %% ../nbs/01_basics.ipynb
#
# ~/.local/lib/python3.8/site-packages/fastcore/basics.py in __call__(self, *args, **kwargs)
#     893             if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     894         fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 895         return self.func(*fargs, **kwargs)
#     896
#     897 # %% ../nbs/01_basics.ipynb
#
# ~/.local/lib/python3.8/site-packages/fastai/learner.py in _call_one(self, event_name)
#     176     def _call_one(self, event_name):
#     177         if not hasattr(event, event_name): raise Exception(f'missing {event_name}')
# --> 178         for cb in self.cbs.sorted('order'): cb(event_name)
#     179
#     180     def _bn_bias_state(self, with_bias): return norm_bias_params(self.model, with_bias).map(self.opt.state)
#
# ~/.local/lib/python3.8/site-packages/fastai/callback/core.py in __call__(self, event_name)
#      62             try: res = getcallable(self, event_name)()
#      63             except (CancelBatchException, CancelBackwardException, CancelEpochException, CancelFitException, CancelStepException, CancelTrainException, CancelValidException): raise
# ---> 64             except Exception as e: raise modify_exception(e, f'Exception occured in `{self.__class__.__name__}` when calling event `{event_name}`:\n\t{e.args[0]}', replace=True)
#      65         if event_name=='after_fit': self.run=True #Reset self.run to True at each end of fit
#      66         return res
#
# ~/.local/lib/python3.8/site-packages/fastai/callback/core.py in __call__(self, event_name)
#      60         res = None
#      61         if self.run and _run:
# ---> 62             try: res = getcallable(self, event_name)()
#      63             except (CancelBatchException, CancelBackwardException, CancelEpochException, CancelFitException, CancelStepException, CancelTrainException, CancelValidException): raise
#      64             except Exception as e: raise modify_exception(e, f'Exception occured in `{self.__class__.__name__}` when calling event `{event_name}`:\n\t{e.args[0]}', replace=True)
#
# ~/.local/lib/python3.8/site-packages/fastai/callback/core.py in before_fit(self)
#      87         self.learn.epoch,self.learn.loss = 0,tensor(0.)
#      88         self.learn.train_iter,self.learn.pct_train = 0,0.
# ---> 89         device = getattr(self.dls, 'device', default_device())
#      90         self.model.to(device)
#      91         if isinstance(self.loss_func, (nn.Module, BaseLoss)): self.loss_func.to(device)
#
# ~/.local/lib/python3.8/site-packages/fastai/torch_core.py in default_device(use)
#     270     else: defaults.use_cuda=use
#     271     if use is None:
# --> 272         if torch.cuda.is_available() or _has_mps(): use = True
#     273     if use:
#     274         if torch.cuda.is_available(): return torch.device(torch.cuda.current_device())
#
# ~/.local/lib/python3.8/site-packages/fastai/torch_core.py in _has_mps()
#     263 def _has_mps():
#     264     if nested_attr(torch, 'backends.mps.is_available', noop)(): return True
# --> 265     return nested_attr(torch, 'backends.mps.is_built', False)()
#     266
#     267 def default_device(use=-1):
#
# TypeError: Exception occured in `TrainEvalCallback` when calling event `before_fit`:
# 	'bool' object is not callable

# %%
# print the evaluation result for the best model
results = predictor.evaluate(validation_data)
print(results)
# Out:
# {'f1_macro': 0.40615379527114787, 'accuracy': 0.8117369607421595, 'balanced_accuracy': 0.38936295971515233, 'mcc': 0.5181652000337745}

# %% [markdown]
# # 4. Apply model

# %%
pred = predictor.predict_proba(validation_data)
pred = pred.rename(columns={0: 'fakeTracks_prob', 
                            1: 'fakeD_prob',
                            2: 'fakeL_prob',
                            3: 'continuum_prob',
                            4: 'combinatorial_prob',
                            5: 'singleBbkg_prob',
                            8: 'sig_prob'})

# %%
pred
# Out:
#         fakeTracks_prob  fakeD_prob  fakeL_prob  continuum_prob  \
# 1              0.006789    0.777897    0.024496        0.010685
# 4              0.006194    0.145342    0.035548        0.035458
# 15             0.012899    0.885186    0.016199        0.047766
# 22             0.012091    0.316573    0.067048        0.049029
# 26             0.004274    0.388828    0.011429        0.521257
# ...                 ...         ...         ...             ...
# 729913         0.018933    0.520465    0.029479        0.418423
# 729920         0.012418    0.867310    0.023997        0.008962
# 729924         0.013535    0.171850    0.045695        0.112353
# 729925         0.013976    0.809941    0.024437        0.007302
# 729933         0.016764    0.038916    0.064170        0.068211
#
#         combinatorial_prob  singleBbkg_prob  sig_prob
# 1                 0.114710         0.030317  0.035106
# 4                 0.249365         0.071790  0.456304
# 15                0.017444         0.003973  0.016532
# 22                0.398908         0.061314  0.095037
# 26                0.043394         0.003799  0.027018
# ...                    ...              ...       ...
# 729913            0.006764         0.002547  0.003390
# 729920            0.039717         0.043069  0.004527
# 729924            0.564511         0.053809  0.038247
# 729925            0.080575         0.060410  0.003358
# 729933            0.258458         0.126494  0.426987
#
# [145987 rows x 7 columns]

# %%
df_pred['mode'].value_counts()
# Out:
# mode
# 1    84008
# 4    18590
# 3    13926
# 8    11672
# 5     7330
# 2     5431
# 0     5030
# Name: count, dtype: int64

# %%
# make predictions on unlabeled sample
df_pred = pd.concat([validation_data, pred], axis=1)
df_pred.query('sig_prob>0.4')['mode'].value_counts()
# Out:
# mode
# 8    4690
# 4     905
# 1     799
# 5     455
# 3     339
# 2     300
# 0     101
# Name: count, dtype: int64
