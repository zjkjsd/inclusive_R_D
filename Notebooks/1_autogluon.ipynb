# %% [markdown]
# # 1. Create the training sample

# %%
# %load_ext autoreload
# %autoreload 2

import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm
from tqdm.auto import tqdm
import sys
sys.path.append('/home/belle/zhangboy/inclusive_R_D/')
import utilities as util
plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.tab20.colors)

training_variables = util.training_variables
columns = util.all_relevant_variables
# Out:
# Welcome to JupyROOT 6.26/14

# %%
# Create Pandas DataFrames (df) from csv files and shuffle the rows
signal_region = '(1.855<D_M) & (D_M<1.885) & (B0_roeMbc_my_mask>5) & (B0_roeDeltae_my_mask<2)'
signal_region += ' & (B0_CMS2_weMbc>4.3) & (-3<B0_CMS0_weDeltae) & (B0_CMS0_weDeltae<2)'

sig_mc = uproot.concatenate([f'../Samples/Generic_MC15ri/e_channel/sigDDst_quaxo_2.root:B0'],
                          library="np",
                          cut = signal_region,
                          filter_branch=lambda branch: branch.name in columns)

generic_mc = uproot.concatenate([f'../Samples/Generic_MC15ri/e_channel/MC15ri_MVA_200fb_quaxo/*.root:B0'],
                          library="np",
                          cut = signal_region,
                          filter_branch=lambda branch: branch.name in columns)

df_sig = pd.DataFrame(sig_mc)
df_generic = pd.DataFrame(generic_mc)

# %%
# separate components
sig_samples=util.get_dataframe_samples_new(df_sig, 'e', template=False)
bkg_samples=util.get_dataframe_samples_new(df_generic, 'e', template=False)

fakeD_sample = pd.concat( [bkg_samples['bkg_FakeD'].query('B0_isContinuumEvent==0'),
                           bkg_samples['bkg_fakeTracks'].query('B0_isContinuumEvent==0')] )

fakeB_sample = pd.concat( [bkg_samples['bkg_combinatorial'],
                           bkg_samples['bkg_singleBbkg']] )

continuum_sample = pd.concat( [bkg_samples['bkg_FakeD'].query('B0_isContinuumEvent==1'),
                               bkg_samples['bkg_fakeTracks'].query('B0_isContinuumEvent==1'),
                               bkg_samples['bkg_continuum']] )

train_dic = {r'$D\tau\nu$':   sig_samples[r'$D\tau\nu$'],
             'fakeD':         fakeD_sample.sample(frac=0.6,random_state=0),
             'fakeB':         fakeB_sample, 
             'continuum':     continuum_sample}

# %%
for i, (name, df) in enumerate(train_dic.items()):
    df['__weight__'] = round(len(train_dic['fakeD'])/len(df))
    df['target'] = i
    print(name, 'target =', i, 'size =', len(df), 
          'weight =', df.iloc[0]['__weight__'])
# Out:
# $D\tau\nu$ target = 0 size = 57718 weight = 6
# fakeD target = 1 size = 374984 weight = 1
# fakeB target = 2 size = 130082 weight = 3
# continuum target = 3 size = 315294 weight = 1

# %%
# create the trainig sample and shuffle, use 'mode' as the training label
df_train = pd.concat( list(train_dic.values()) ).sample(frac=1)

# %%
df_train['target'].value_counts()
# Out:
# target
# 1    372579
# 3    317064
# 2    128643
# 0     57718
# Name: count, dtype: int64

# %%
print(df_train.isna().sum()[df_train.isna().sum()!=0])
# Out:
# B0_mcDaughter_0_PDG    19419
# B0_mcDaughter_1_PDG    19419
# B0_mcPDG               19419
# D_K_mcPDG               3406
# D_mcPDG                15236
# ell_mcPDG               2643
# dtype: int64

# %%
# define relevant variables to your training
target_column = ['target']
feature_column = training_variables + ['__weight__']

df_train_sub = df_train[target_column + feature_column].copy().reset_index(drop=True)

# %%
with uproot.recreate(f'../AutogluonModels/train.root') as file:
    file['B0'] = df_train_sub

# %% [markdown]
# # 2. Setup autogluon and perfrom the training

# %%
from autogluon.tabular import TabularPredictor
import uproot
import pandas as pd

train_sub = uproot.concatenate([f'../AutogluonModels/train.root:B0'],library="np")
df_train_sub = pd.DataFrame({k:v for k, v in train_sub.items() if k!='index'})

# Split the training set to train and validation
train_data = df_train_sub.sample(frac=0.8, random_state=0)
validation_data = df_train_sub.drop(train_data.index)

# %%
# Define and fit the AutoGluon classifier
hyperpar = {
    "GBM": [
        'GBMLarge',
    ],
#     "NN_TORCH": {
#         "num_epochs": 50,
#         'num_layers': 3,
#         'hidden_size': 128,
#         "dropout_prob": 0.5,       # Add dropout to reduce overfitting
#         "batch_size": 32,
#         "weight_decay": 1e-4,      # Apply L2 regularization
#         "learning_rate": 0.01,     # Adjust learning rate
#     },
}

hyperpar_tuner = {
        'num_trials': 20,
        'searcher': 'auto',
    }

ag = TabularPredictor(label='mode', eval_metric='f1_macro') # many more configuration
predictor = ag.fit(train_data=train_data, #tuning_data=validation_data,
                   presets='good_quality', save_bag_folds=True,
                   excluded_model_types=['FASTAI'],time_limit=10*60,
                   hyperparameters=hyperpar,
                   hyperparameter_tune_kwargs=hyperpar_tuner)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241127_093018"
# Presets specified: ['good_quality']
# Warning: hyperparameter tuning is currently experimental and may cause the process to hang.
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels/ag-20241127_093018/ds_sub_fit/sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 287 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 313 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 313s
# AutoGluon will save models to "AutogluonModels/ag-20241127_093018"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.8.8
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Tue Oct 3 11:12:36 EDT 2023
# CPU Count:          128
# Memory Avail:       344.40 GB / 502.95 GB (68.5%)
# Disk Space Avail:   101784.05 GB / 197682.00 GB (51.5%)
# ===================================================
# Train Data Rows:    583949
# Train Data Columns: 44
# Label Column:       mode
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 7
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    352707.03 MB
# 	Train Data (Original)  Memory Usage: 98.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 44 | ['B0_R2', 'B0_thrustOm', 'B0_cosTBTO', 'B0_cosTBz', 'B0_KSFWV3', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 44 | ['B0_R2', 'B0_thrustOm', 'B0_cosTBTO', 'B0_cosTBz', 'B0_KSFWV3', ...]
# 	1.4s = Fit runtime
# 	44 features in original data used to generate 44 features in processed data.
# 	Train Data (Processed) Memory Usage: 98.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.47s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1_macro'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'GBM': ['GBMLarge'],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Excluded models: [] (Specified by `excluded_model_types`)
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 207.64s of the 311.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=16, gpus=0, memory=0.24%)
# 	0.1046	 = Validation score   (f1_macro)
# 	213.37s	 = Training   runtime
# 	1.49s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 311.53s of the 84.36s of remaining time.
# 	Ensemble Weights: {'LightGBMLarge_BAG_L1': 1.0}
# 	0.1046	 = Validation score   (f1_macro)
# 	0.23s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Excluded models: [] (Specified by `excluded_model_types`)
# Fitting 1 L2 models ...
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 83.99s of the 83.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=16, gpus=0, memory=0.27%)
# 	0.1046	 = Validation score   (f1_macro)
# 	112.46s	 = Training   runtime
# 	1.8s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 311.53s of the -33.55s of remaining time.
# 	Ensemble Weights: {'LightGBMLarge_BAG_L1': 1.0}
# 	0.1046	 = Validation score   (f1_macro)
# 	6.78s	 = Training   runtime
# 	0.1s	 = Validation runtime
# AutoGluon training complete, total runtime = 353.52s ... Best model: "WeightedEnsemble_L2"
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	6.12s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBMLarge_BAG_L1': 1.0}
# 	0.23s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	7.07s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBMLarge_BAG_L1': 1.0}
# 	6.78s	 = Training   runtime
# Updated best model to "LightGBMLarge_BAG_L1_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "LightGBMLarge_BAG_L1_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 14.95s ... Best model: "LightGBMLarge_BAG_L1_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241127_093018")

# %% [markdown]
# # 3. Load and inspect model

# %%
predictor = TabularPredictor.load("../AutogluonModels/ag-20241203_203215")

# %%
# display the trained models
predictor.leaderboard(validation_data, extra_metrics=['roc_auc_ovo_macro',])
# Out:
#                  model  score_test  roc_auc_ovo_macro  score_val eval_metric  \
# 0             LightGBM    0.751681           0.956966   0.636566    f1_macro
# 1  WeightedEnsemble_L2    0.710542           0.930040   0.660752    f1_macro
# 2       NeuralNetTorch    0.657478           0.891127   0.650468    f1_macro
# 3           LightGBMXT    0.631751           0.900392   0.615657    f1_macro
# 4        LightGBMLarge    0.590424           0.873907   0.568789    f1_macro
#
#    pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  \
# 0        3.089117       3.003950  3609.481638                 3.089117
# 1        5.678794       3.772579  9999.670002                 0.037952
# 2        1.963876       0.488263  6114.567853                 1.963876
# 3        0.481176       0.035729    61.705243                 0.481176
# 4        0.106673       0.201838   213.653203                 0.106673
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                3.003950        3609.481638            1       True
# 1                0.042799           0.262064            2       True
# 2                0.488263        6114.567853            1       True
# 3                0.035729          61.705243            1       True
# 4                0.201838         213.653203            1       True
#
#    fit_order
# 0          2
# 1          5
# 2          3
# 3          1
# 4          4

# %%
predictor.model_best
# Out:
# 'WeightedEnsemble_L2'

# %%
predictor.feature_importance(validation_data, model='NeuralNetTorch')
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['__weight__']
#                            importance    stddev       p_value  n  p99_high  \
# B0_roeDeltae_my_mask         0.098912  0.005242  9.427916e-07  5  0.109704
# B0_KSFWV3                    0.091661  0.003121  1.611075e-07  5  0.098088
# B0_KSFWV8                    0.075848  0.010736  4.690689e-05  5  0.097953
# B0_KSFWV14                   0.071542  0.004668  2.163491e-06  5  0.081154
# B0_R2                        0.067793  0.004615  2.561987e-06  5  0.077296
# B0_roeMbc_my_mask            0.057597  0.009210  7.584488e-05  5  0.076561
# B0_vtxDDSig                  0.046862  0.008282  1.123283e-04  5  0.063914
# D_A1FflightDistanceSig_IP    0.036054  0.005973  8.716660e-05  5  0.048353
# D_daughterInvM_1_2           0.027804  0.008988  1.145921e-03  5  0.046310
# D_vtxReChi2                  0.025690  0.006908  5.711935e-04  5  0.039913
# D_daughterInvM_0_1           0.023613  0.004922  2.139782e-04  5  0.033748
# B0_thrustOm               -0.004185
# B0_CC3                    -0.005532
# B0_CC2                     0.004859
# B0_roeEextra_my_mask      -0.004495
# B0_KSFWV4                  0.003269
# B0_Lab5_weMissPTheta       0.001837
# B0_CC1                    -0.003089
# B0_TagVReChi2IP           -0.003433
# B0_CC4                     0.002457
# B0_cosTBz                 -0.001407
# B0_KSFWV9                 -0.005434
# B0_CC5                    -0.007789
# B0_cosTBTO                -0.001935
# B0_KSFWV6                 -0.001619
# B0_roel_DistanceSig_dis   -0.005644
# B0_KSFWV13                -0.001351
# B0_KSFWV15                -0.005657
# B0_CC6                    -0.006376
# D_pi2_pValue              -0.003775
# B0_KSFWV5                 -0.004692
# B0_KSFWV18                -0.008739
# B0_CC9                    -0.000978
# B0_KSFWV7                 -0.005322
# B0_CC8                    -0.007577
# D_K_pValue                -0.003586
# B0_roeCharge_my_mask      -0.007710
# D_pi1_pValue              -0.004525
# B0_KSFWV17                -0.005052
# B0_KSFWV10                -0.007461
# B0_CC7                    -0.005314

# %% [markdown]
# # 4. Apply model

# %%
pred = predictor.predict_proba(validation_data)
pred = pred.rename(columns={0: 'fakeTracks_prob', 
                            1: 'fakeD_prob',
                            2: 'fakeL_prob',
                            3: 'continuum_prob',
                            4: 'combinatorial_prob',
                            5: 'singleBbkg_prob',
                            8: 'sig_prob'})

# %%
pred
# Out:
#         fakeTracks_prob  fakeD_prob  fakeL_prob  continuum_prob  \
# 1              0.006789    0.777897    0.024496        0.010685
# 4              0.006194    0.145342    0.035548        0.035458
# 15             0.012899    0.885186    0.016199        0.047766
# 22             0.012091    0.316573    0.067048        0.049029
# 26             0.004274    0.388828    0.011429        0.521257
# ...                 ...         ...         ...             ...
# 729913         0.018933    0.520465    0.029479        0.418423
# 729920         0.012418    0.867310    0.023997        0.008962
# 729924         0.013535    0.171850    0.045695        0.112353
# 729925         0.013976    0.809941    0.024437        0.007302
# 729933         0.016764    0.038916    0.064170        0.068211
#
#         combinatorial_prob  singleBbkg_prob  sig_prob
# 1                 0.114710         0.030317  0.035106
# 4                 0.249365         0.071790  0.456304
# 15                0.017444         0.003973  0.016532
# 22                0.398908         0.061314  0.095037
# 26                0.043394         0.003799  0.027018
# ...                    ...              ...       ...
# 729913            0.006764         0.002547  0.003390
# 729920            0.039717         0.043069  0.004527
# 729924            0.564511         0.053809  0.038247
# 729925            0.080575         0.060410  0.003358
# 729933            0.258458         0.126494  0.426987
#
# [145987 rows x 7 columns]

# %%
df_pred['mode'].value_counts()
# Out:
# mode
# 1    84008
# 4    18590
# 3    13926
# 8    11672
# 5     7330
# 2     5431
# 0     5030
# Name: count, dtype: int64

# %%
# make predictions on unlabeled sample
df_pred = pd.concat([validation_data, pred], axis=1)
df_pred.query('sig_prob>0.4')['mode'].value_counts()
# Out:
# mode
# 8    4690
# 4     905
# 1     799
# 5     455
# 3     339
# 2     300
# 0     101
# Name: count, dtype: int64
